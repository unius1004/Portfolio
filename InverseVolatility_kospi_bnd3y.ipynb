# %%
from setting import *

# %matplotlib inline

# %%
# kodex200 : 069500, kbstar국고채3년 : 114100 
tickers = ['069500','114100']
names = ['kodex200','kbstar bond 3year']

# %%
data = getHistoryByFdr(tickers, names)
print('data \n', data)
# Out:
# data
#              kodex200  kbstar bond 3year
# Date
# 2009-07-29     16044            76226.0
# 2009-07-30     16182            76367.0
# 2009-07-31     16444            76217.0
# 2009-08-03     16471            75959.0
# 2009-08-04     16500            75965.0
# ...              ...                ...
# 2022-11-25     31630           108375.0
# 2022-11-28     31245           108300.0
# 2022-11-29     31600           108205.0
# 2022-11-30     32075           108335.0
# 2022-12-01     32265           108310.0
#
# [3297 rows x 2 columns]

# %%
equalWeight = Equal_Weight_BT(data, name='Equal Weight')
invVolWeight = InvVol_Weight_BT(data, name='Inverse Volatility')
report = bt.run(equalWeight)

# %%
report.plot()
plt.title('변동성 역가중 일간 수익률 추이')

print(report.display())
print(report.display_monthly_returns())
# Out:
# Stat                 Equal Weight
# -------------------  --------------
# Start                2009-07-28
# End                  2022-12-01
# Risk-free rate       0.00%
#
# Total Return         74.45%
# Daily Sharpe         0.54
# Daily Sortino        0.88
# CAGR                 4.26%
# Max Drawdown         -20.22%
# Calmar Ratio         0.21
#
# MTD                  0.28%
# 3m                   2.26%
# 6m                   -3.80%
# YTD                  -9.54%
# 1Y                   -7.59%
# 3Y (ann.)            4.15%
# 5Y (ann.)            1.99%
# 10Y (ann.)           3.29%
# Since Incep. (ann.)  4.26%
#
# Daily Sharpe         0.54
# Daily Sortino        0.88
# Daily Mean (ann.)    4.61%
# Daily Vol (ann.)     8.49%
# Daily Skew           -0.09
# Daily Kurt           4.73
# Best Day             4.06%
# Worst Day            -3.63%
#
# Monthly Sharpe       0.55
# Monthly Sortino      0.95
# Monthly Mean (ann.)  4.49%
# Monthly Vol (ann.)   8.21%
# Monthly Skew         -0.25
# Monthly Kurt         1.13
# Best Month           7.47%
# Worst Month          -6.98%
#
# Yearly Sharpe        0.50
# Yearly Sortino       1.34
# Yearly Mean          4.23%
# Yearly Vol           8.52%
# Yearly Skew          0.12
# Yearly Kurt          -0.68
# Best Year            18.72%
# Worst Year           -9.54%
#
# Avg. Drawdown        -1.60%
# Avg. Drawdown Days   44.13
# Avg. Up Month        1.79%
# Avg. Down Month      -1.83%
# Win Year %           69.23%
# Win 12m %            67.55%
# None
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec    YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
#   2009   0      0      0      0      0      0      0      0.85   3.45  -2.87   0.23   4.39   6.02
#   2010  -2.21  -0.05   3.79   1.98  -2.96   1.46   2.24   0.13   3.89   0.47   1.79   4.28  15.51
#   2011   0.03  -2.62   4.62   2.32  -0.77  -1.47   0.45  -5.74  -2.37   4.65  -1.38   0.02  -2.72
#   2012   3.96   1.94  -0.1    0.02  -3.56   0.33   1.76   0.25   2.55  -2.14   0.93   2.17   8.18
#   2013  -0.87   2.27  -0.6   -1.36   0.77  -3.95   1.39   0.82   2.21   1.33   0.29  -0.19   1.97
#   2014  -1.99   1.11   0.11  -0.33   1.19   0.3    2.25  -0.82  -1.23  -0.87   0.79  -1.17  -0.75
#   2015   1.71   0.14   1.49   1.88  -0.94  -1.72  -1.53  -2.21   1.36   2.99  -1.32  -0.02   1.69
#   2016  -1.51   1.13   2.21  -0.06  -0.3    0.61   1.59   0.86   0.27  -0.54  -0.63   2.01   5.72
#   2017   1.77   0.32   2.27   1.22   3.29   1.21   0.45  -1.02   1.33   2.37  -1.03   0.36  13.18
#   2018   1.25  -2.81   0.63   1.35  -1.73  -1.47  -0.2    0.65   0.22  -5.85   1.62  -0.91  -7.27
#   2019   4.7   -0.31  -0.82   1.46  -3.51   2.95  -1.64  -1.29   2.86   0.33   0.27   3.8    8.8
#   2020  -1.27  -2.6   -5.73   4.73   2.11   2.46   3.55   1.19   0.76  -1.57   7.47   7.01  18.72
#   2021   2.18   0.65   0.5    0.97   0.49   1.23  -1.39  -0.5   -2.41  -2.21  -1.27   3.37   1.44
#   2022  -4.95   0.56   0.2   -1.81  -0     -6.98   3.49  -1.1   -6.64   3.33   4.44   0.28  -9.54
# None
